# %%
import pandas
import numpy

# %%
import_libs = [
    pandas,
    numpy,
]

print("\n".join([f"{lib.__name__}\t\t{lib.__version__}" for lib in import_libs]))
# Out:
# pandas		3.0.0
# numpy		2.4.1
